# %%
user='jalmeida',
password='Brcsaude@2051',
account='DMVBWQM-YE08051'

# %%
import snowflake.connector

# Gets the version
ctx = snowflake.connector.connect(
    user='jalmeida',
    password='Brcsaude@2051',
    account='DMVBWQM-YE08051'
    )
cs = ctx.cursor()

# %%
import streamlit as st
# Executar uma consulta no Snowflake
query = "SELECT * FROM OUR_FIRST_DB.PUBLIC.LOAN_PAYMENT"
cursor = ctx.cursor()
cursor.execute(query)
data = cursor.fetchall()


# Criar um aplicativo Streamlit
st.title('Dados do Snowflake')
st.write('Aqui estão os dados de sua consulta:')

# Exibir os dados em uma tabela
st.write(data)
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.18.215.173:8501
#   External URL: http://179.113.132.245:8501
#
# NOTE: When using the `ipython kernel` entry point, Ctrl-C will not work.
#
# To exit, you will have to explicitly quit this process, by either sending
# "quit" from a client, or using Ctrl-\ in UNIX-like environments.
#
# To read more about this, see https://github.com/ipython/ipython/issues/2049
#
#
# To connect another client to this kernel, use:
#     --existing kernel-22203.json
# [IPKernelApp] ERROR | Unable to initialize signal:
# Traceback (most recent call last):
#   File "/home/dev_jean/desenvolvimento/streamlit_snowflakes/.venv/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 699, in initialize
#     self.init_signal()
#   File "/home/dev_jean/desenvolvimento/streamlit_snowflakes/.venv/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 543, in init_signal
#     signal.signal(signal.SIGINT, signal.SIG_IGN)
# ...

# %%
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.18.215.173:8501
#   External URL: http://179.113.132.245:8501
#
# NOTE: When using the `ipython kernel` entry point, Ctrl-C will not work.
#
# To exit, you will have to explicitly quit this process, by either sending
# "quit" from a client, or using Ctrl-\ in UNIX-like environments.
#
# To read more about this, see https://github.com/ipython/ipython/issues/2049
#
#
# To connect another client to this kernel, use:
#     --existing kernel-22096.json
# [IPKernelApp] ERROR | Unable to initialize signal:
# Traceback (most recent call last):
#   File "/home/dev_jean/desenvolvimento/streamlit_snowflakes/.venv/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 699, in initialize
#     self.init_signal()
#   File "/home/dev_jean/desenvolvimento/streamlit_snowflakes/.venv/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 543, in init_signal
#     signal.signal(signal.SIGINT, signal.SIG_IGN)
# ...

# %%
import snowflake.connector

# Configurar a conexão com o Snowflake

user='jalmeida',
password='Brcsaude@2051',
account='DMVBWQM-RM32821',
warehouse='COMPUTE_WH'
database= "SNOWFLAKE_SAMPLE_DATA"
schema= "INFORMATION_SCHEMA"
role="accountadmin"
#snowsql -a dmvbwqm-ye08051 -u jalmeida -r accountadmin -w COMPUTE_WH -d SNOWFLAKE_SAMPLE_DATA -s INFORMATION_SCHEMA
try:
    # Configurar a conexão com o Snowflake
    conn = snowflake.connector.Connect(
        user=user,
        password=password,
        account=account,
        role=role,
        warehouse=warehouse,
        autocommit=True
  )
except snowflake.connector.errors.ProgrammingError as e:
    # Se houver um erro de autenticação ou de conexão, imprima uma mensagem de erro
    print(f"Erro de conexão com o Snowflake: {e}")
